# %% [markdown]
# ## This notebook is to perform feature selection for test set

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows',999)
pd.set_option('display.max_columns',50)

import warnings
warnings.filterwarnings("ignore")

# %%
testset = pd.read_csv('testscaled.csv')

# %%
testset.shape
# Out:
# (1576, 39)

# %%
testset.head()
# Out:
#    population  renter_occupied_households  pct_renter_occupied  evictions  \
# 0    0.353668                    0.306091             0.471125   0.408135
# 1    1.000000                    1.000000             1.000000   1.000000
# 2    0.544309                    0.758580             0.822573   1.000000
# 3    0.823400                    1.000000             0.872562   0.408135
# 4    0.979577                    0.894810             0.573748   0.795002
#
#    rent_burden  pct_white  pct_af_am  pct_hispanic  pct_am_ind  pct_asian  \
# 0     0.468848   0.900918   0.103759      0.180592    0.145647   0.086622
# 1     0.723493   0.190619   1.000000      0.335200    0.102602   0.818184
# 2     0.672285   0.306056   1.000000      0.520647    0.184684   0.347333
# 3     0.606532   0.284789   0.366146      1.000000    0.236332   1.000000
# 4     0.613306   0.532580   1.000000      0.250700    0.382640   0.636197
#
#    pct_nh_pi  pct_multiple  pct_other  poverty_rate  pct_civilian_labor  \
# ...

# %%
testset.describe()
# Out:
#         population  renter_occupied_households  pct_renter_occupied  \
# count  1576.000000                 1576.000000          1576.000000
# mean      0.321117                    0.316207             0.512685
# std       0.328733                    0.335104             0.195287
# min       0.000000                    0.000000             0.000000
# 25%       0.079336                    0.068427             0.375000
# 50%       0.177360                    0.160516             0.485793
# 75%       0.447602                    0.441056             0.625000
# max       1.000000                    1.000000             1.000000
#
#          evictions  rent_burden    pct_white    pct_af_am  pct_hispanic  \
# count  1576.000000  1576.000000  1576.000000  1576.000000   1576.000000
# mean      0.231701     0.495793     0.705605     0.276576      0.330381
# std       0.284126     0.211260     0.253012     0.354214      0.316778
# ...

# %%
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1576 entries, 0 to 1575
# Data columns (total 39 columns):
# population                                    1576 non-null float64
# renter_occupied_households                    1576 non-null float64
# pct_renter_occupied                           1576 non-null float64
# evictions                                     1576 non-null float64
# rent_burden                                   1576 non-null float64
# pct_white                                     1576 non-null float64
# pct_af_am                                     1576 non-null float64
# pct_hispanic                                  1576 non-null float64
# pct_am_ind                                    1576 non-null float64
# pct_asian                                     1576 non-null float64
# pct_nh_pi                                     1576 non-null float64
# pct_multiple                                  1576 non-null float64
# ...

# %%
testset = testset[['population','pct_asian','poverty_rate','pct_adult_obesity',
                   'pct_physical_inactivity','pct_adults_with_high_school_diploma',
                   'pct_adults_bachelors_or_higher','death_rate_per_1k']]

# %%
testset.head()
# Out:
#    population  pct_asian  poverty_rate  pct_adult_obesity  \
# 0    0.353668   0.086622      0.446371           0.375000
# 1    1.000000   0.818184      0.746092           0.364583
# 2    0.544309   0.347333      0.677516           0.713542
# 3    0.823400   1.000000      0.722351           0.661458
# 4    0.979577   0.636197      0.407101           0.406250
#
#    pct_physical_inactivity  pct_adults_with_high_school_diploma  \
# 0                 0.687500                             0.619426
# 1                 0.393382                             0.169853
# 2                 0.599265                             0.441808
# 3                 0.643382                             0.298511
# 4                 0.371324                             0.331054
#
#    pct_adults_bachelors_or_higher  death_rate_per_1k
# 0                        0.364862           0.517399
# 1                        0.911415           0.394389
# 2                        0.431389           0.483949
# ...

# %%
testset.shape
# Out:
# (1576, 8)

# %%
#testset.to_csv('testcleaned.csv',index=False)
