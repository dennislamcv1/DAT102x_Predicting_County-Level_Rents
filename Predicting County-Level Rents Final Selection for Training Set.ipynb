# %% [markdown]
# ### This notebook is to finalize which features to be trained

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows',2000)
pd.set_option('display.max_columns',50)
pd.set_option('display.width',1000)

import warnings
warnings.filterwarnings("ignore")
np.random.seed(5)

# %%
df = pd.read_csv('trainscaled.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 40 columns):
# population                                    1562 non-null float64
# renter_occupied_households                    1562 non-null float64
# pct_renter_occupied                           1562 non-null float64
# evictions                                     1562 non-null float64
# rent_burden                                   1562 non-null float64
# pct_white                                     1562 non-null float64
# pct_af_am                                     1562 non-null float64
# pct_hispanic                                  1562 non-null float64
# pct_am_ind                                    1562 non-null float64
# pct_asian                                     1562 non-null float64
# pct_nh_pi                                     1562 non-null float64
# pct_multiple                                  1562 non-null float64
# ...

# %%
df.shape
# Out:
# (1562, 40)

# %%
df = df[['pct_adults_bachelors_or_higher','poverty_rate','death_rate_per_1k','pct_asian','pct_adults_with_high_school_diploma',
         'rent_burden','pct_aged_65_years_and_older','pct_adult_obesity','pct_multiple','population',
         'pct_physical_inactivity','pct_adults_with_some_college','gross_rent']]

# %%
df.head()
# Out:
#    pct_adults_bachelors_or_higher  poverty_rate  death_rate_per_1k  pct_asian  pct_adults_with_high_school_diploma  rent_burden  pct_aged_65_years_and_older  pct_adult_obesity  pct_multiple  population  pct_physical_inactivity  pct_adults_with_some_college  gross_rent
# 0                        0.415881      0.163225           0.453269   0.215669                             0.452178     0.030726                     0.620098           0.515625      0.154963    0.023278                 0.733696                      0.813736       577.0
# 1                        1.000000      0.301803           0.000000   0.057134                             0.120183     0.412926                     0.066176           0.218750      0.314188    0.064244                 0.030797                      0.495366       844.0
# ...

# %%
df.shape
# Out:
# (1562, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 13 columns):
# pct_adults_bachelors_or_higher         1562 non-null float64
# poverty_rate                           1562 non-null float64
# death_rate_per_1k                      1562 non-null float64
# pct_asian                              1562 non-null float64
# pct_adults_with_high_school_diploma    1562 non-null float64
# rent_burden                            1562 non-null float64
# pct_aged_65_years_and_older            1562 non-null float64
# pct_adult_obesity                      1562 non-null float64
# pct_multiple                           1562 non-null float64
# population                             1562 non-null float64
# pct_physical_inactivity                1562 non-null float64
# pct_adults_with_some_college           1562 non-null float64
# gross_rent                             1562 non-null float64
# dtypes: float64(13)
# memory usage: 158.8 KB

# %%
df.describe()
# Out:
#        pct_adults_bachelors_or_higher  poverty_rate  death_rate_per_1k    pct_asian  pct_adults_with_high_school_diploma  rent_burden  pct_aged_65_years_and_older  pct_adult_obesity  pct_multiple   population  pct_physical_inactivity  pct_adults_with_some_college   gross_rent
# count                     1562.000000   1562.000000        1562.000000  1562.000000                          1562.000000  1562.000000                  1562.000000        1562.000000   1562.000000  1562.000000              1562.000000                   1562.000000  1562.000000
# mean                         0.420082      0.470485           0.498212     0.325477                             0.501116     0.496731                     0.507084           0.489837      0.419322     0.315221                 0.498382                      0.498353   690.869398
# ...

# %%
#df.to_csv('traincleaned.csv',index=False)

# %% [markdown]
# ### Import categorical features

# %%
dfcat = pd.read_csv('traincat.csv')

# %%
dfcat.head()
# Out:
#    row_id county_code    state                                               rucc                                    urban_influence        economic_typology  gross_rent
# 0       0     8e686a7  fb8cab1  Nonmetro - Completely rural or less than 2,500...  Noncore adjacent to micro area and does not co...  Manufacturing-dependent         577
# 1       1     d1b5fc5  842bd12  Nonmetro - Completely rural or less than 2,500...          Micropolitan not adjacent to a metro area               Recreation         844
# 2       2     19a463b  2b7da97  Nonmetro - Urban population of 2,500 to 19,999...  Noncore not adjacent to a metro/micro area and...               Recreation         700
# 3       3     1711ab7  5029ed4  Nonmetro - Urban population of 2,500 to 19,999...  Noncore not adjacent to a metro/micro area and...           Nonspecialized         592
# ...

# %%
dfcat = dfcat.drop(labels=['row_id','county_code','state','gross_rent'],axis=1)

# %%
dfcat.head()
# Out:
#                                                 rucc                                    urban_influence        economic_typology
# 0  Nonmetro - Completely rural or less than 2,500...  Noncore adjacent to micro area and does not co...  Manufacturing-dependent
# 1  Nonmetro - Completely rural or less than 2,500...          Micropolitan not adjacent to a metro area               Recreation
# 2  Nonmetro - Urban population of 2,500 to 19,999...  Noncore not adjacent to a metro/micro area and...               Recreation
# 3  Nonmetro - Urban population of 2,500 to 19,999...  Noncore not adjacent to a metro/micro area and...           Nonspecialized
# 4  Nonmetro - Completely rural or less than 2,500...  Noncore adjacent to micro area and does not co...           Farm-dependent

# %%
dfcat.shape
# Out:
# (1562, 3)

# %%
dfcat['rucc'].value_counts()
# Out:
# Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area                         301
# Metro - Counties in metro areas of 1 million population or more                                  219
# Nonmetro - Completely rural or less than 2,500 urban population, not adjacent to a metro area    215
# Nonmetro - Urban population of 2,500 to 19,999, not adjacent to a metro area                     206
# Metro - Counties in metro areas of 250,000 to 1 million population                               193
# Metro - Counties in metro areas of fewer than 250,000 population                                 165
# Nonmetro - Completely rural or less than 2,500 urban population, adjacent to a metro area        120
# Nonmetro - Urban population of 20,000 or more, adjacent to a metro area                          101
# Nonmetro - Urban population of 20,000 or more, not adjacent to a metro area                       42
# Name: rucc, dtype: int64

# %%
#dfcat = dfcat.drop(labels=['urban_influence','economic_typology'],axis=1)

# %%
dfcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 3 columns):
# rucc                 1562 non-null object
# urban_influence      1562 non-null object
# economic_typology    1562 non-null object
# dtypes: object(3)
# memory usage: 36.7+ KB

# %%
finaldf = pd.concat([df,dfcat],axis=1)

# %%
finaldf
# Out:
#       pct_adults_bachelors_or_higher  poverty_rate  death_rate_per_1k  pct_asian  pct_adults_with_high_school_diploma  rent_burden  pct_aged_65_years_and_older  pct_adult_obesity  pct_multiple  population  pct_physical_inactivity  pct_adults_with_some_college  gross_rent                                               rucc                                    urban_influence                   economic_typology
# 0                           0.415881      0.163225           0.453269   0.215669                             0.452178     0.030726                     0.620098           0.515625      0.154963    0.023278                 0.733696                      0.813736     577.000  Nonmetro - Completely rural or less than 2,500...  Noncore adjacent to micro area and does not co...             Manufacturing-dependent
# ...

# %%
finaldf = finaldf[['pct_adults_bachelors_or_higher','poverty_rate','death_rate_per_1k','pct_asian','pct_adults_with_high_school_diploma',
         'rent_burden','pct_aged_65_years_and_older','pct_adult_obesity','pct_multiple','population',
         'pct_physical_inactivity','pct_adults_with_some_college','rucc','urban_influence',
         'economic_typology','gross_rent' ]]

# %%
finaldf
# Out:
#       pct_adults_bachelors_or_higher  poverty_rate  death_rate_per_1k  pct_asian  pct_adults_with_high_school_diploma  rent_burden  pct_aged_65_years_and_older  pct_adult_obesity  pct_multiple  population  pct_physical_inactivity  pct_adults_with_some_college                                               rucc                                    urban_influence                   economic_typology  gross_rent
# 0                           0.415881      0.163225           0.453269   0.215669                             0.452178     0.030726                     0.620098           0.515625      0.154963    0.023278                 0.733696                      0.813736  Nonmetro - Completely rural or less than 2,500...  Noncore adjacent to micro area and does not co...             Manufacturing-dependent     577.000
# ...

# %%
finaldf.shape
# Out:
# (1562, 16)

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 16 columns):
# pct_adults_bachelors_or_higher         1562 non-null float64
# poverty_rate                           1562 non-null float64
# death_rate_per_1k                      1562 non-null float64
# pct_asian                              1562 non-null float64
# pct_adults_with_high_school_diploma    1562 non-null float64
# rent_burden                            1562 non-null float64
# pct_aged_65_years_and_older            1562 non-null float64
# pct_adult_obesity                      1562 non-null float64
# pct_multiple                           1562 non-null float64
# population                             1562 non-null float64
# pct_physical_inactivity                1562 non-null float64
# pct_adults_with_some_college           1562 non-null float64
# rucc                                   1562 non-null object
# urban_influence                        1562 non-null object
# ...

# %%
#finaldf.to_csv('traincombo.csv',index=False)
